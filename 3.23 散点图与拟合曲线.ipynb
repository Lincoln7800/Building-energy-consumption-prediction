# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt #导入
import seaborn as sns

# %%
data = pd.read_excel('多维数组汇总.xlsx',encoding = 'gbk')

# %%
data.head(5)
# Out:
#        room  num  date  value  Maximum temperature  minimum temperature  \
# 0  14_  104  104  9月1日   6.20                 29.3                 32.1
# 1  14_  104  104  9月2日   4.85                 27.3                 30.2
# 2  14_  104  104  9月3日   4.75                 26.2                 31.3
# 3  14_  104  104  9月4日   5.77                 27.0                 32.8
# 4  14_  104  104  9月5日   4.35                 26.3                 30.8
#
#    average temperature  humidity  Sunshine hours  category  direction  \
# 0                 27.3        82             9.1         1          0
# 1                 24.9        86             4.2         1          0
# 2                 22.6        70            10.8         1          0
# 3                 21.0        63             8.5         1          0
# 4                 20.1        63            11.7         1          0
#
#    floor number  Number of households season
# 0             1                     2    sum
# ...

# %%
plt.figure(figsize=(15, 10))
sns.set(style="ticks",font_scale=1.7,palette="muted", color_codes=True)                                     #设置主题
# sns.boxplot(data['category'],y = data['value'], hue=data['season'], palette="PRGn",sym='')   #palette 调色板
sns.violinplot(data['direction'],y = data['value'], hue=data['category'],palette="PRGn",sym='') 
plt.show()
